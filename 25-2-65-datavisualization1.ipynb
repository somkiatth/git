# %% [markdown]
# <a href="https://colab.research.google.com/github/somkiatth/git/blob/master/datavisualization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
mark =[2,3,5,5,9]

plt.plot(mark)

year=[2000,2001,2002,2003,2004,]
plt.plot(year,mark)

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Feb 25 19:35:00 2022

@author: somkiat
"""

import pandas as pd
import matplotlib.pyplot as plt

#import seaborn as sns

marks=[0.98,0.85,0.97,0.91,0.92,0.87,0.93]
plt.plot(marks)
year=[2015,2016,2017,2018,2019,2020,2021]
plt.plot(year,marks)

plt.xlabel('Academic year')
plt.ylabel('Averagge passing score')
plt.title('University score')

df=pd.DataFrame(marks)
df
df.plot(kind='hist')


age =[22,33,45,1,77,9,8,1,22,23,1,7,2,66,45,66,44]

bin=[0,20,40,60,80,100]
plt.hist(age, bins=bin, histtype='bar')


import numpy as np

x=np.array([1,2,3,4,5])
y=np.array([10,20,30,40,50])
plt.scatter(x,y,marker='*')




x=np.array([[1,2],[3,4],[3,4],[5,7]])
#y=np.array({[11,21],[13,41],[31,14],[15,27]})
plt.scatter(x[:,0],x[:,1],marker='*')





z=np.array([1,2,3,4,5])
plt.pie(z)


l1=['yoga','zumba','aerobics','no exercise']
z=np.array([35,25,25,15])
plt.pie(z,labels=l1)


url=("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")

df=pd.read_csv(url)
#pd.set_option("display",None)
#df=pd.read_csv(r'D:\india2\24-2-65\loan_small.csv')
df.isnull().sum()

df.plot(x='Rank',y=['P25th','P75th','Median'])


x=df['Median']
x.plot(kind='hist')
df
df.Major_code
pd.DataFrame.mean(df.Major_code)



df[df['Major_category']=='Engineering']['Median'].plot(kind='hist')
