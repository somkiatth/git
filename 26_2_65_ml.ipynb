# %% [markdown]
# <a href="https://colab.research.google.com/github/somkiatth/git/blob/master/26_2_65_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
num=np.array([26,34,56,77,55])
df=pd.DataFrame(num)
df
avg=df.mean()
print(avg)
std=df.std()
print(std)
df.plot(kind='hist')
df1=pd.DataFrame()


for i in num:
    x=(i-avg)/std
    df1=df1.append(x,ignore_index=True)
df1

from sklearn.preprocessing import StandardScaler
data=[[0,0],[1,1],[2,3]]
data
scaler=StandardScaler()
scaler.fit(data)
scaler.mean_
scaler.scale_
scaler.transform(data)
# Out:
# 0    49.6
# dtype: float64
# 0    20.132064
# dtype: float64
# array([[-1.22474487, -1.06904497],
#        [ 0.        , -0.26726124],
#        [ 1.22474487,  1.33630621]])

# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""



import numpy as np
import pandas as pd
num=np.array([26,34,56,77,55])
df=pd.DataFrame(num)
df
avg=df.mean()
print(avg)
std=df.std()
print(std)
df.plot(kind='hist')
df1=pd.DataFrame()


for i in num:
    x=(i-avg)/std
    df1=df1.append(x,ignore_index=True)
df1

from sklearn.preprocessing import StandardScaler
data=[[0,0],[1,1],[2,3]]
data
scaler=StandardScaler()
scaler.fit(data)
scaler.mean_
scaler.scale_
scaler.transform(data)



#python standard scaler class



from sklearn.preprocessing import StandardScaler
data=[[0,0],[0,1],[1,2],[2,3]]
data



scaler=StandardScaler()



#train the data using the standard scaler
scaler.fit(data)



#print the mean and the std dev
scaler.mean_



scaler.scale_



#perform the standardization by scaling each data point



scaler.transform(data)


X=np.array([[1,-1,2],[2,0,0],[0,1,-1]])



X
#min_max_scaler
#y = (x – min) / (max – min)


from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()



X_new=min_max_scaler.fit_transform(X)



X_new

#exercise
#Read the loan _small dataset and scale the numeric columns to
#scaled alues by using standardization and normalization
dt=pd.read_csv('D:\\dataset\\loan_small.csv')
dt
dt.head(10)




dt.iloc[:,2:5]
#remove the rows containing null values
dt1=dt.iloc[:,2:5].dropna()
dt1
dt1.plot(kind='hist')
#load the standard scaler module
from sklearn.preprocessing import StandardScaler
#create a class reference
scaler=StandardScaler()


#Scale the values in each column using standardization
new_dt1=scaler.fit_transform(dt1)



new_dt1
#load the min max scaler
from sklearn.preprocessing import MinMaxScaler



#create a class reference



min_max_scaler=MinMaxScaler()
#Scale the values in each column using normalization
new_dt2=min_max_scaler.fit_transform(dt1)
new_dt2
x=pd.DataFrame(new_dt2)
x.plot(kind='hist')




#exercise 3
from sklearn.preprocessing import Normalizer
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
df=pd.read_csv('D:\\dataset\\pima-indians-diabetes.csv',names=names)
df
df1=df.iloc[:,0:8]



array=df.values
x=array[:,0:8]
x



scaler=Normalizer()
Normalized_data=scaler.fit_transform(df1)




Normalized_data




#exercise 4



from sklearn.preprocessing import Binarizer
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
df=pd.read_csv('D:\\dataset\\pima-indians-diabetes.csv',names=names)
df
df1=df.iloc[:,0:8]



#create a binarizer object



binarizer=Binarizer(threshold=5.0).fit(df1)



binary_data=binarizer.transform(df1)




from sklearn.preprocessing import LabelEncoder



le=LabelEncoder()
input=['cricket','badminton','golf','tenis','volleyball']
le.fit(input)


for i,item in enumerate(le.classes_):
    print(item,'--------->',i)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
#example of label encoder
courses=['PGDBDA','PGDAC','PGDAI','PGDGIS','PGDMC']
lang=['Python','Java','Python','R prog','C++']
code=["C1","C2","C3","C4","C5"]



df=pd.DataFrame({"course":courses,"language":lang,"code":code})
df



from sklearn.preprocessing import LabelEncoder



le=LabelEncoder()
#we added a column which will store the
# encoded values of language column
df['lang_encoded']=le.fit_transform(df['language'])
df

#one hot encoding
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
ohe.fit(df)
df2=pd.DataFrame(ohe.fit_transform(df[['language']]).toarray())



df2
df_encoded=pd.concat([df,df2],axis=1)



df_encoded
# Out:
# 0    49.6
# dtype: float64
# 0    20.132064
# dtype: float64
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-99600dfd3eb9> in <module>()
#      95 #Read the loan _small dataset and scale the numeric columns to
#      96 #scaled alues by using standardization and normalization
# ---> 97 dt=pd.read_csv('D:\\dataset\\loan_small.csv')
#      98 dt
#      99 dt.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
