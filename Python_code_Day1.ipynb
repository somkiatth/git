# %% [markdown]
# <a href="https://colab.research.google.com/github/somkiatth/git/blob/master/Python_code_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 10 10:05:38 2022

@author: PADMESH
"""
print("Hello World")
var1="Hello, World"
print(var1)
x = 2
print(x)
y = "2"
print(y)
type(x)
type(y)
z=5.6
z


#how to use comments
# This is a block comment.
greeting = "Hello, World"
print(greeting) # This is an inline comment
print("#1")
fname = input("Input your First Name : ") 
lname=input()
print(lname)

#strings in single quote 
str1 = 'good'
print(str1)
type(str1)# check the type of the variable.
print(type(str1)) 

#strings in double quote 

str2 = "very good"
print(str2)
print(type(str2))

print(str1,str2)
print(str1,"and",str2)
print(type(str), type(str2))

str1 = """good"""
print(str1)
type(str1)

str3 = '''Hello'''
print(str3)

# triple quotes string can extend multiple lines
str4 = """Hello all
           Welcome to CDAC"""
print(str4)

str5 = "Hello all\
           Welcome to CDAC"
print(str5)

str6 = '''Hello all
           Welcome to CDAC'''

print(str6)
str7 = '''Hello all
           Welcome to "CDAC Noida"'''
print(str7)
str8 = """Hello all Welcome to CDAC's Machine Learning class"""
print(str8)

#Functions in string

#length of a string
str3
len(str3)
str8
len(str8)

str=""
# Test truth value of empty string
print(bool(str))
str="hello"
# Test truth value of non-empty string "x"
print(bool(str))
#A string is considered to be true in Python if it is not an empty string. 

#test if string "o" is present in string "hello" at least once.
"o" in str
"a" in str

s="cdac"
#s.lower(), s.upper() -- returns the lowercase or uppercase version of the string
s.lower()
s.upper()
s.isupper()
s.islower()
#s.strip() 
#-- returns a string with whitespace removed from the start and end
s="cdac "
s.strip()
#s.isdigit()/s.isspace()... 
#-- tests if all the string chars are in the various character classes
s.isdigit()
s.isspace()
#s.startswith('c') returns true if it starts with c, s.endswith('c') if it ends with c 
s.startswith('c')
s.endswith('c')
s.startswith('C')
s.endswith('A')
#str.capitalize(): 
#--returns a copy of the string with its first character capitalized.
s.capitalize()
#-- tests if the string starts or ends with the given other string
s.find('c')  
str1 = 'I love python'
str2 = 'python'
str1.find(str2)
#str.count(substring): 
#counts how many times a substring occurs in the string.
# You can also specify the start and the stop index for the string.
str1.count(str2)
#--searches for the given other string (not a regular expression) within s, and returns the first index where it begins or -1 if not found
#s.replace('old', 'new') 
s.replace('cdac', 'cdac noida') 
s
s=s.replace('cdac', 'cdac noida') 
s
#-- returns a string where all occurrences of 'old' have been replaced by 'new'
#s.split('delim') 
s.split()
s
#find the index of a "c" in a string "abcde"
s.index("i")
#string Slicing
#Accessing string characters in Python
str = 'python programming'
print('str = ', str)


#first character
print('str[0] = ', str[0])

#last character
print('str[-1] = ', str[-1])

#slicing 2nd to 5th character
print('str[1:5] = ', str[1:5])

#slicing 6th to 2nd last character
print('str[5:-2] = ', str[5:-2])
str[-7:-4]
# Python String Operations
str1 = 'Hello'
str2 ='World!'

# using +
print('str1 + str2 = ', str1 + str2)

# using *
print('str1 * 3 =', str1 * 3)
#Arithmatic operation on numbers in Python
str1="Hello"
str2="Hello"
str3="HELLO"
#String Comparison using == Copy
print(str1 == str2)
print(str1 == str3)


#how to  print 8 blank lines
print (8 * "\n")
print ("\n\n\n\n\n\n\n\n\n")

#Working with Numbers

x=10
y=5
x+y
x*y
x/y
x//y
x%y
x=input()
x
type(x)
z=int(x)+y
z

x=input()
x
x+y
int(x)+y
#Convert User Input to Int Copy


x=int(input("Enter a Number: "))

x
type(x)
# assign a decimal number to a variable float_var
f1 = 5.6

# assign another decimal number to a variable float_var1
f2 = 6.7

# print the sum of the two decimal numbers
print(f1 + f2)

#Use the float() function to convert string, int to float.

float('5.5')

float('5')

float('     -5')

float('1e3')

float('-Infinity')

float('inf')


#How to print the volume of a sphere 
pi = 3.1415926535897931 
r= 6.0 
V= 4.0/3.0*pi* r**3 
print('The volume of the sphere is: ',V)


#list in python


name=['Siddhi','akanksha','priti']
name
print(name)
lang = ["Python","Java","R-prog"]
print(lang)
number= [100,200,45,300,190]

number

number
x=list()
type(x)
dir(x)
x.append("a")
x
x.append("b")
x
x.reverse()
x
list2=[1,2,3,'text']
list2[3]
list2[1]=200
list2
list2.append(50)
list2
list2[-1]
list2[-4]
len(list2)
list2.insert(3,6)
list2
list2.insert(4,10)
list2
list2.sort
list2

nums = [3, 41, 12, 9, 74, 15]
print( len(nums))

max(nums)
min(nums)
sum(nums)
sum(nums)/len(nums)


#creating Tuple
my_tuple=() #create tuple
print(my_tuple) 

my_tuple2 = (1, 2, 3, 'cdac') #access elements
my_tuple2[2]
my_tuple2[1]=1000
my_tuple2
for x in my_tuple2:
    print(x)

d1={'name':'siddhi','city':'NOIDA'} 
d1
city_dict={'city':['Delhi','Gurgaon','noida'],'population':[400000,600000,300000]}
city_dict
city_dict

print("today' s date is 27")
print('welcome to "CDAC NOIDA"')
